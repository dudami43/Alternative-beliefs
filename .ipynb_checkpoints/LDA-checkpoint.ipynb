# %%
import re
import glob
import json
import warnings
import networkx as nx
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import seaborn as sns
from sklearn.decomposition import LatentDirichletAllocation as LDA
from sklearn.feature_extraction.text import CountVectorizer
from wordcloud import WordCloud, STOPWORDS 
from graphviz import Digraph
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from heapq import nlargest
from pyLDAvis import sklearn as sklearn_lda
from pyLDAvis import gensim
import pickle 
import pyLDAvis
import os
os.environ["PATH"] += os.pathsep + 'C:\\graphviz\\bin'
warnings.simplefilter("ignore", DeprecationWarning)

# %%
import sys
# !{sys.executable} -m spacy download en
import re, numpy as np, pandas as pd
from pprint import pprint

from collections import Counter
from matplotlib.patches import Rectangle
from matplotlib.ticker import FuncFormatter

from sklearn.manifold import TSNE
from bokeh.plotting import figure, output_file, show
from bokeh.models import Label
from bokeh.io import output_notebook

# Gensim
import gensim, spacy, logging, warnings
import gensim.corpora as corpora
from gensim.utils import lemmatize, simple_preprocess
from gensim.models import CoherenceModel
import matplotlib.pyplot as plt
import nltk

# %%
def sent_to_words(sentences):
    for sent in sentences:
        sent = re.sub('\S*@\S*\s?', '', sent)  # remove emails
        sent = re.sub('\s+', ' ', sent)  # remove newline chars
        sent = re.sub("\'", "", sent)  # remove single quotes
        sent = gensim.utils.simple_preprocess(str(sent), deacc=True) 
        yield(sent)

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\meomi\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
stop_words.extend(['from', 'subject', 're', 'edu', 'use', 'not', 'would', 'say', 'could', '_', 'be', 'know', 'good', 'go', 'get', 'do', 'done', 'try', 'many', 'some', 'nice', 'thank', 'think', 'see', 'rather', 'easy', 'easily', 'lot', 'lack', 'make', 'want', 'seem', 'run', 'need', 'even', 'right', 'line', 'even', 'also', 'may', 'take', 'come'])

# %%
def process_words(texts, stop_words=stop_words, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
    """Remove Stopwords, Form Bigrams, Trigrams and Lemmatization"""
    texts = [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts]
    texts = [bigram_mod[doc] for doc in texts]
    texts = [trigram_mod[bigram_mod[doc]] for doc in texts]
    texts_out = []
    nlp = spacy.load('en_core_web_sm', disable=['parser', 'ner'])
    for sent in texts:
        doc = nlp(" ".join(sent)) 
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    # remove stopwords once more after lemmatization
    texts_out = [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts_out]    
    return texts_out

# %%
def get_dist_sentiment(lista):
    dist_sentiment = dict()
    for each in lista:
        aux = list()
        for item in graphs[each]:
            aux.append(graphs[each].nodes[item]['sentiment'])
        dist_sentiment[each] = np.array(aux)
    positives = dict()
    negatives = dict()
    for i in dist_sentiment:
        k = int(len(dist_sentiment[i])*0.5)
        if(k != 0):
            number = max(nlargest(k, dist_sentiment[i]))
        else:
            number = dist_sentiment[i][0]
        if(number >= 0):
            positives[i] = dist_sentiment[i]
        else:
            negatives[i] = dist_sentiment[i]
    return dist_sentiment, positives, negatives

# %%
def plot_10_most_common_words(count_data, count_vectorizer):
    import matplotlib.pyplot as plt
    words = count_vectorizer.get_feature_names()
    total_counts = np.zeros(len(words))
    for t in count_data:
        total_counts+=t.toarray()[0]
    
    count_dict = (zip(words, total_counts))
    count_dict = sorted(count_dict, key=lambda x:x[1], reverse=True)[0:10]
    words = [w[0] for w in count_dict]
    counts = [w[1] for w in count_dict]
    x_pos = np.arange(len(words)) 
    
    plt.figure(2, figsize=(15, 15/1.6180))
    plt.subplot(title='10 most common words')
    sns.set_context("notebook", font_scale=1.25, rc={"lines.linewidth": 2.5})
    sns.barplot(x_pos, counts, palette='husl')
    plt.xticks(x_pos, words, rotation=90) 
    plt.xlabel('words')
    plt.ylabel('counts')
    plt.show()

# %%
def print_topics(model, count_vectorizer, n_top_words):
    words = count_vectorizer.get_feature_names()
    for topic_idx, topic in enumerate(model.components_):
        print("\nTopic #%d:" % topic_idx)
        print(" ".join([words[i]
                        for i in topic.argsort()[:-n_top_words - 1:-1]]))

# %%
def sentences_chart(lda_model, corpus, start = 0, end = 13):
    corp = corpus[start:end]
    mycolors = [color for name, color in mcolors.TABLEAU_COLORS.items()]

    fig, axes = plt.subplots(end-start, 1, figsize=(20, (end-start)*0.95), dpi=160)       
    axes[0].axis('off')
    for i, ax in enumerate(axes):
        if i > 0:
            corp_cur = corp[i-1] 
            topic_percs, wordid_topics, wordid_phivalues = lda_model[corp_cur]
            word_dominanttopic = [(lda_model.id2word[wd], topic[0]) for wd, topic in wordid_topics]    
            ax.text(0.01, 0.5, "Doc " + str(i-1) + ": ", verticalalignment='center',
                    fontsize=16, color='black', transform=ax.transAxes, fontweight=700)

            # Draw Rectange
            topic_percs_sorted = sorted(topic_percs, key=lambda x: (x[1]), reverse=True)
            ax.add_patch(Rectangle((0.0, 0.05), 0.99, 0.90, fill=None, alpha=1, 
                                   color=mycolors[topic_percs_sorted[0][0]], linewidth=2))

            word_pos = 0.06
            for j, (word, topics) in enumerate(word_dominanttopic):
                if j < 14:
                    ax.text(word_pos, 0.5, word,
                            horizontalalignment='left',
                            verticalalignment='center',
                            fontsize=16, color=mycolors[topics],
                            transform=ax.transAxes, fontweight=700)
                    word_pos += .009 * len(word)  # to move the word for the next iter
                    ax.axis('off')
            ax.text(word_pos, 0.5, '. . .',
                    horizontalalignment='left',
                    verticalalignment='center',
                    fontsize=16, color='black',
                    transform=ax.transAxes)       

    plt.subplots_adjust(wspace=0, hspace=0)
    plt.suptitle('Sentence Topic Coloring for Documents: ' + str(start) + ' to ' + str(end-2), fontsize=22, y=0.95, fontweight=700)
    plt.tight_layout()
    plt.show()

# %%
def topics_per_document(model, corpus, start=0, end=1):
    corpus_sel = corpus[start:end]
    dominant_topics = []
    topic_percentages = []
    for i, corp in enumerate(corpus_sel):
        topic_percs, wordid_topics, wordid_phivalues = model[corp]
        dominant_topic = sorted(topic_percs, key = lambda x: x[1], reverse=True)[0][0]
        dominant_topics.append((i, dominant_topic))
        topic_percentages.append(topic_percs)
    return(dominant_topics, topic_percentages)

# %%
files = glob.glob("dados//believes//*.json")

# %%
quotes2 = glob.glob("dados//believes//replies_449836320572321792_*.json")

# %%
graphs = dict()
for filename in files:
    DG = nx.DiGraph()
    with open(filename, 'r', encoding="utf8") as f: 
        data = json.load(f)
        for tweet in data:
            DG.add_node(tweet)
            if(data[tweet]['replie_to'] is not None):
                DG.add_node(data[tweet]['replie_to'])
                DG.add_edge(tweet,data[tweet]['replie_to'])
            for attr in data[tweet]:
                DG.node[tweet][attr] = data[tweet][attr]
    graphs[filename] = DG

# %%
dist_sentiment, positives, negatives = get_dist_sentiment(quotes2)

# %%
lista = positives
df = pd.DataFrame(columns = ['original', 'text'])
for each in lista: 
    X = list()
    for item in graphs[each]:
        val = str(graphs[each].nodes[item]['text'])
        val = re.sub(r'(https|http)?:\/\/(\w|\.|\/|\?|\=|\&|\%)*\b', '', val, flags=re.MULTILINE)
        df = df.append({'text': val, 'original': each}, ignore_index=True)

# %%
df['processed_text'] = df['text'].map(lambda x: re.sub('[,\.!?]', '', x))
df['processed_text'] = df['processed_text'].map(lambda x: x.lower())
df['processed_text'] = df['processed_text'].map(lambda x: x.lower())

# %%
long_string = ','.join(list(df['processed_text'].values))

# %%
wordcloud = WordCloud(background_color="white", max_words=5000, contour_width=3, contour_color='steelblue')
wordcloud.generate(long_string)
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x1F0FCBF0F60>

# %%
# Initialise the count vectorizer with the English stop words
count_vectorizer = CountVectorizer(stop_words='english')# Fit and transform the processed titles
count_data = count_vectorizer.fit_transform(df['processed_text'])# Visualise the 10 most common words
plot_10_most_common_words(count_data, count_vectorizer)

# %%
# Tweak the two parameters below
number_topics = 5
number_words = 10# Create and fit the LDA model
lda = LDA(n_components=number_topics, n_jobs=-1)
lda.fit(count_data)# Print the topics found by the LDA model
print("Topics found via LDA:")
print_topics(lda, count_vectorizer, number_words)
# Out:
# Topics found via LDA:
#
# Topic #0:
# realdonaldtrump time katyturnbc trump 2014 vaccine son having president maybe
#
# Topic #1:
# medical anti today just gemini realdonaldtrump kids doctor opinion right
#
# Topic #2:
# realdonaldtrump katyturnbc vaccines trump like don people cause autism doctor
#
# Topic #3:
# trump know child did vaccine children said vaccines time dont
#
# Topic #4:
# trump potus just pictwittercom dr autism vaccines brain exactly vaccine

# %%
data = df.text.values.tolist()
data_words = list(sent_to_words(data))

# %%
# Build the bigram and trigram models
bigram = gensim.models.Phrases(data_words, min_count=5, threshold=100) # higher threshold fewer phrases.
trigram = gensim.models.Phrases(bigram[data_words], threshold=100)  
bigram_mod = gensim.models.phrases.Phraser(bigram)
trigram_mod = gensim.models.phrases.Phraser(trigram)

# %%
data_ready = process_words(data_words)

# %%
id2word = corpora.Dictionary(data_ready)

# %%
corpus = [id2word.doc2bow(text) for text in data_ready]

# %%
#frequencia de cada palavra em cada documento
[[(id2word[id], freq) for id, freq in cp] for cp in corpus]
# Out:
# [[('cage', 1), ('cept', 1), ('kid', 1)],
#  [('anyone', 1), ('figure', 1), ('mean', 1)],
#  [('kid', 1), ('literally', 1), ('time', 1), ('vaccinate', 1), ('vaccine', 1)],
#  [('vaccine', 1), ('approach', 1), ('nuance', 1), ('trump', 1)],
#  [('autism', 1),
#   ('baron', 1),
#   ('begin', 1),
#   ('campaign', 1),
#   ('circulate', 1),
#   ('measle', 1),
#   ('rumor', 1),
#   ('talk', 1),
#   ('vaccination', 1)],
#  [('hear', 1), ('interesting', 1), ('never', 1)],
#  [],
#  [('vaccine', 1),
#   ('already', 1),
#   ('answer', 1),
#   ('anti', 1),
#   ('ask', 1),
#   ('people', 1),
#   ('question', 1),
#   ('shirt', 1)],
#  [('muckenfuk', 1), ('oldie', 1)],
#  [('normal', 1)],
#  [],
#  [('vaccine', 1),
#   ('course', 1),
#   ('doc', 1),
#   ('doctor', 1),
#   ('immunization', 2),
#   ('miss', 1),
#   ('obviously', 1),
#   ('parent', 2),
#   ('pay', 1),
#   ('pediatrician', 1),
#   ('single', 1),
#   ('visit', 3),
#   ('work', 1)],
#  [],
#  [],
#  [('time', 2),
#   ('vaccine', 1),
#   ('almost', 1),
#   ('comment', 1),
#   ('next', 1),
#   ('search', 1),
#   ('shot', 1),
#   ('spread', 2),
#   ('stage', 1),
#   ('yrs', 1)],
#  [('care', 1), ('entire', 1), ('let', 1), ('opinion', 1)],
#  [('care', 1), ('apparently', 1), ('pal', 1)],
#  [('defend', 1),
#   ('full', 1),
#   ('give', 1),
#   ('imagine', 1),
#   ('lmaooo', 1),
#   ('old', 1),
#   ('story', 1),
#   ('tweet', 1),
#   ('year', 1)],
#  [('mean', 1),
#   ('vaccine', 1),
#   ('autism', 1),
#   ('comment', 1),
#   ('clearly', 1),
#   ('elite', 1),
#   ('help', 1),
#   ('kind', 1),
#   ('link', 2),
#   ('plain', 1),
#   ('pretty', 1),
#   ('really', 1),
#   ('state', 1),
#   ('stupidity', 1),
#   ('tier', 1),
#   ('wrong', 1)],
#  [('opinion', 1),
#   ('give', 1),
#   ('tweet', 1),
#   ('help', 1),
#   ('link', 1),
#   ('really', 1),
#   ('absolutely', 1),
#   ('case', 1),
#   ('context', 1),
#   ('entitle', 1),
#   ('glad', 1),
#   ('honestly', 1)],
#  [('full', 1),
#   ('give', 1),
#   ('story', 1),
#   ('defense', 1),
#   ('feel', 1),
#   ('form', 1)],
#  [('literally', 1), ('vaccine', 1), ('autism', 1), ('context', 1)],
#  [('vaccine', 1),
#   ('people', 1),
#   ('case', 1),
#   ('actually', 1),
#   ('agree', 1),
#   ('anything', 1),
#   ('bet', 1),
#   ('circlejerk', 1),
#   ('defensive', 1),
#   ('everyone', 2),
#   ('happen', 1),
#   ('hardly', 1),
#   ('inform', 1),
#   ('notice', 1),
#   ('post', 1),
#   ('simply', 1),
#   ('statement', 1),
#   ('whole', 1)],
#  [('wrong', 1), ('lmao', 1)],
#  [('imagine', 1),
#   ('informed', 1),
#   ('judge', 1),
#   ('lose', 1),
#   ('negative', 1),
#   ('someone', 1),
#   ('stance', 1),
#   ('thing', 1)],
#  [('vaccinate', 1),
#   ('vaccine', 1),
#   ('clearly', 1),
#   ('autistic', 1),
#   ('sarcasm', 1)],
#  [('hear', 1),
#   ('help', 1),
#   ('really', 1),
#   ('case', 1),
#   ('defensive', 1),
#   ('post', 1),
#   ('man', 1),
#   ('much', 1),
#   ('necessary', 1),
#   ('second', 1),
#   ('totally', 1)],
#  [('vaccination', 2),
#   ('doctor', 1),
#   ('actually', 1),
#   ('bias', 1),
#   ('dnp', 1),
#   ('doctorate', 1),
#   ('home', 1),
#   ('license', 1),
#   ('major', 1),
#   ('medical', 2),
#   ('mother', 1),
#   ('nursing', 1),
#   ('practice', 1),
#   ('preme', 1),
#   ('report', 1),
#   ('revoke', 1),
#   ('stupid', 1)],
#  [('kid', 1),
#   ('anyone', 1),
#   ('vaccination', 2),
#   ('let', 1),
#   ('opinion', 1),
#   ('old', 1),
#   ('away', 1),
#   ('believe', 1),
#   ('carrier', 1),
#   ('child', 1),
#   ('desert', 1),
#   ('die', 1),
#   ('enough', 1),
#   ('general', 1),
#   ('idgaf', 1),
#   ('infant', 1),
#   ('island', 1),
#   ('keep', 1),
#   ('kill', 1),
#   ('polio', 1),
#   ('population', 1),
#   ('vacciate', 1)],
#  [('people', 1),
#   ('around', 1),
#   ('bad', 1),
#   ('barely', 1),
#   ('choice', 1),
#   ('cringey', 1),
#   ('dance', 1),
#   ('gottem', 1),
#   ('lol', 1),
#   ('probably', 1),
#   ('rent', 1)],
#  [('pretty', 1),
#   ('everyone', 1),
#   ('little', 1),
#   ('project', 1),
#   ('sure', 1),
#   ('thread', 1)],
#  [('people', 1),
#   ('capable', 1),
#   ('guess', 1),
#   ('ignorant', 1),
#   ('shit', 1),
#   ('successful', 1)],
#  [('vaccine', 1),
#   ('autism', 1),
#   ('vaccination', 1),
#   ('parent', 1),
#   ('work', 1),
#   ('give', 1),
#   ('link', 1),
#   ('believe', 1),
#   ('child', 2),
#   ('accordingly', 1),
#   ('check', 1),
#   ('crazy', 1),
#   ('president', 1),
#   ('proper', 1),
#   ('schedule', 1),
#   ('still', 1),
#   ('wellness', 1)],
#  [('たから出馬表明より前てす', 1),
#   ('たたし', 1),
#   ('てはない', 1),
#   ('みたいなことを言っていますね', 1),
#   ('オレは', 1),
#   ('オレを嫌う負け犬ともへ', 1),
#   ('反ワクチン', 1),
#   ('期間をかけて分散すへきた', 1)],
#  [('とてもまともな意見表明てして', 1), ('本当にありかとうこさいます', 1), ('第三者の言葉をそのまま信用せす', 1)],
#  [('perfect', 1), ('sense', 1)],
#  [],
#  [],
#  [('duuuuude', 1), ('find', 1)],
#  [('vaccine', 1), ('search', 1), ('plenty', 1), ('realdonaldtrump', 1)],
#  [('brain', 1), ('crap', 1), ('holy', 1), ('potus', 1), ('share', 1)],
#  [('vaccine', 1), ('potus', 1), ('crime', 1), ('humanity', 1)],
#  [],
#  [('potus', 1)],
#  [('time', 1),
#   ('spread', 1),
#   ('abort', 1),
#   ('analysis', 1),
#   ('animal', 1),
#   ('contaminate', 1),
#   ('death', 1),
#   ('dna', 1),
#   ('fetal', 1),
#   ('illness', 1),
#   ('injury', 1),
#   ('person', 1),
#   ('random', 1),
#   ('rare', 1),
#   ('restructure', 1),
#   ('risk', 1),
#   ('serious', 1),
#   ('shoot', 1),
#   ('understand', 1)],
#  [('bet', 1), ('listening', 1)],
#  [('time', 1),
#   ('let', 4),
#   ('year', 1),
#   ('thing', 1),
#   ('child', 1),
#   ('still', 1),
#   ('risk', 1),
#   ('adverse', 1),
#   ('identify', 1),
#   ('ingredient', 1),
#   ('look', 1),
#   ('reaction', 1),
#   ('safety', 1),
#   ('study', 1)],
#  [('potus', 1), ('love', 1)],
#  [('time', 1),
#   ('thing', 1),
#   ('always', 1),
#   ('decla', 1),
#   ('draintheswamp', 1),
#   ('factsfirst', 1),
#   ('factsmatter', 2),
#   ('faean', 1),
#   ('greatawakene', 1),
#   ('justice', 1),
#   ('kag', 1),
#   ('maga', 1),
#   ('qanon', 1),
#   ('qarmypic', 1),
#   ('realnew', 1),
#   ('saveamerica', 1),
#   ('stablegeniuse', 1),
#   ('top', 1),
#   ('truth', 1),
#   ('wakeupamerica', 1),
#   ('wethepeople', 1),
#   ('wga', 1),
#   ('wwg', 1)],
#  [('vaccine', 2),
#   ('potus', 1),
#   ('daughter', 1),
#   ('disagree', 1),
#   ('impair', 1),
#   ('mmr', 1),
#   ('safer', 1),
#   ('stagger', 1),
#   ('vision', 1)],
#  [('already', 1),
#   ('anti', 1),
#   ('parent', 1),
#   ('actually', 1),
#   ('medical', 1),
#   ('crime', 1),
#   ('humanity', 1),
#   ('identify', 1),
#   ('correctly', 1),
#   ('dead', 1),
#   ('injure', 2),
#   ('label', 1),
#   ('law', 1),
#   ('pharmedia', 1),
#   ('protect', 1),
#   ('stop', 2),
#   ('suffer', 1),
#   ('tyranny', 1),
#   ('vaxxe', 1),
#   ('vaxxer', 2),
#   ('warn', 1)],
#  [('spread', 1),
#   ('child', 1),
#   ('shoot', 1),
#   ('adult', 1),
#   ('choose', 1),
#   ('dangerous', 1),
#   ('end', 1),
#   ('rix', 1),
#   ('tip', 1),
#   ('way', 1)],
#  [('fight', 1), ('freedom', 1)],
#  [('connection', 1), ('dear', 1), ('irrefutable', 1), ('lord', 1)],
#  [('back', 1), ('dqbpx', 1), ('eqcm', 1), ('science', 1), ('toopic', 1)],
#  [('vaccine', 1),
#   ('sure', 1),
#   ('add', 1),
#   ('particular', 1),
#   ('research', 1),
#   ('well', 1)],
#  [('vaccinate', 1),
#   ('state', 1),
#   ('child', 2),
#   ('choose', 1),
#   ('concern', 1),
#   ('decision', 1),
#   ('federal', 1),
#   ('fit', 1),
#   ('government', 1),
#   ('key', 1),
#   ('parental', 1),
#   ('period', 1)],
#  [('vaccine', 1),
#   ('really', 1),
#   ('find', 1),
#   ('corvelva', 1),
#   ('ejyohfmsnq', 1),
#   ('html', 1),
#   ('mmrv', 2),
#   ('priorix', 1),
#   ('tetra', 1),
#   ('vaccinegate', 1)],
#  [('trump', 1),
#   ('always', 1),
#   ('connect', 1),
#   ('gemini', 3),
#   ('haha', 1),
#   ('mess', 1),
#   ('messenger', 1),
#   ('pence', 1),
#   ('straighten', 1)],
#  [('dilley', 1), ('feed', 1), ('fess', 1), ('topic', 1)],
#  [('border', 1),
#   ('bring', 1),
#   ('deadly', 1),
#   ('disease', 1),
#   ('invader', 1),
#   ('shut', 1)],
#  [('pay', 1),
#   ('spread', 1),
#   ('find', 1),
#   ('dna', 1),
#   ('truth', 1),
#   ('damage', 1),
#   ('follow', 1),
#   ('harmful', 1),
#   ('investigate', 1),
#   ('money', 1),
#   ('outside', 1),
#   ('shed', 1),
#   ('source', 1),
#   ('toxic', 1),
#   ('uninformed', 1),
#   ('untested', 1),
#   ('vax', 1),
#   ('virus', 1),
#   ('woefully', 1)],
#  [('vaccine', 1),
#   ('feel', 1),
#   ('judge', 1),
#   ('damage', 1),
#   ('ability', 1),
#   ('baseline', 1),
#   ('btw', 1),
#   ('cognitive', 1),
#   ('effect', 1),
#   ('point', 1),
#   ('side', 1),
#   ('smart', 1),
#   ('wait', 1)],
#  [('exactly', 1)],
#  [('time', 1),
#   ('vaccine', 1),
#   ('enough', 1),
#   ('assault', 1),
#   ('calculate', 1),
#   ('immune', 1),
#   ('leave', 1),
#   ('prudent', 1),
#   ('recovery', 1),
#   ('sound', 1),
#   ('system', 1),
#   ('tiny', 1)],
#  [('feed', 1), ('reserve', 1), ('tell', 1)],
#  [('vaccine', 1),
#   ('give', 1),
#   ('back', 1),
#   ('annual', 1),
#   ('pet', 1),
#   ('slowly', 1),
#   ('step', 1),
#   ('together', 1)],
#  [('scary', 1)],
#  [('lol', 1), ('sense', 1), ('common', 1)],
#  [('ago', 1), ('verbatim', 1), ('week', 1)],
#  [('vaccine', 1),
#   ('people', 2),
#   ('full', 1),
#   ('year', 1),
#   ('random', 1),
#   ('love', 1),
#   ('always', 1),
#   ('side', 1),
#   ('argue', 1),
#   ('husband', 1),
#   ('middle', 1),
#   ('reason', 1),
#   ('throttle', 1)],
#  [('fb', 1), ('jxo', 1)],
#  [('kid', 1), ('spread', 1), ('care', 1), ('cautious', 1), ('overly', 1)],
#  [('shot', 1),
#   ('spread', 1),
#   ('thing', 1),
#   ('autistic', 2),
#   ('believe', 1),
#   ('child', 2),
#   ('daughter', 1),
#   ('age', 1),
#   ('center', 1),
#   ('first', 1),
#   ('friend', 1),
#   ('ready', 1),
#   ('school', 1),
#   ('scope', 1),
#   ('spot', 1),
#   ('test', 1),
#   ('young', 1)],
#  [('kid', 1),
#   ('vaccine', 2),
#   ('vaccination', 1),
#   ('people', 1),
#   ('sense', 1),
#   ('exactly', 1),
#   ('common', 1),
#   ('camp', 1),
#   ('geometrically', 1),
#   ('load', 1),
#   ('oppose', 1),
#   ('pump', 1),
#   ('whatsoever', 1)],
#  [('trump', 1),
#   ('work', 1),
#   ('agree', 1),
#   ('happen', 1),
#   ('sure', 1),
#   ('still', 1),
#   ('study', 1),
#   ('mmr', 1),
#   ('admin', 1),
#   ('jr', 1),
#   ('plan', 1),
#   ('rfk', 1),
#   ('suppose', 1),
#   ('thought', 1),
#   ('wld', 1)],
#  [('vaccine', 1), ('follow', 1), ('shill', 1), ('slay', 1)],
#  [('vaccine', 1),
#   ('brain', 2),
#   ('dangerous', 1),
#   ('damage', 1),
#   ('aluminum', 2),
#   ('blood', 1),
#   ('cause', 1),
#   ('collect', 1),
#   ('deem', 1),
#   ('dose', 1),
#   ('ingested', 1),
#   ('inject', 2),
#   ('manufacturer', 1),
#   ('nanoparticle', 1),
#   ('safe', 1),
#   ('small', 1),
#   ('stream', 1)],
#  [('fbpf', 1), ('pdfmz', 1)],
#  [('actually', 1), ('notice', 1), ('pointed', 1)],
#  [('freedom', 1),
#   ('force', 1),
#   ('long', 1),
#   ('mention', 1),
#   ('punish', 1),
#   ('today', 1)],
#  [('potus', 1)],
#  [('talk', 1),
#   ('potus', 1),
#   ('way', 1),
#   ('tell', 1),
#   ('exciting', 1),
#   ('show', 1),
#   ('watch', 1)],
#  [('apparently', 1), ('show', 1), ('listen', 1)],
#  [('indeed', 1)],
#  [('talk', 1), ('ben', 1), ('carson', 1), ('debate', 1), ('early', 1)],
#  [('big', 1), ('collective', 1)],
#  [('lol', 1), ('amazing', 1)],
#  [('people', 1),
#   ('post', 1),
#   ('enough', 1),
#   ('point', 1),
#   ('long', 1),
#   ('ass', 1),
#   ('enjoy', 1),
#   ('fucking', 1),
#   ('head', 1),
#   ('significance', 1)],
#  [('gemini', 1)],
#  [],
#  [('trump', 1), ('injection', 1)],
#  [('still', 1),
#   ('brain', 1),
#   ('aluminum', 1),
#   ('accumulate', 1),
#   ('faith', 1),
#   ('permanently', 1)],
#  [('anti', 1),
#   ('spread', 1),
#   ('state', 1),
#   ('honestly', 1),
#   ('medical', 1),
#   ('law', 2),
#   ('fight', 1),
#   ('freedom', 1),
#   ('allow', 1),
#   ('deep', 1),
#   ('delay', 1),
#   ('dem', 1),
#   ('new', 1),
#   ('provax', 1),
#   ('push', 1),
#   ('retrovirus', 1),
#   ('skip', 1),
#   ('speak', 1)],
#  [('exactly', 1)],
#  [('base', 1), ('timestamp', 1)],
#  [],
#  [('grammar', 1), ('toaster', 1)],
#  [],
#  [('vaccine', 1),
#   ('shot', 1),
#   ('whole', 1),
#   ('way', 1),
#   ('shut', 1),
#   ('immune', 1),
#   ('system', 2),
#   ('load', 1),
#   ('dose', 1),
#   ('alcohol', 1),
#   ('exceptjesus', 1),
#   ('high', 1),
#   ('lotta', 1),
#   ('night', 1)],
#  [('thing', 1),
#   ('today', 1),
#   ('correct', 1),
#   ('damn', 1),
#   ('hilarious', 1),
#   ('rock', 1)],
#  [('lol', 1),
#   ('shit', 1),
#   ('holy', 1),
#   ('scope', 1),
#   ('awesome', 1),
#   ('ball', 1),
#   ('twat', 1)],
#  [('cool', 1)],
#  [('vaccine', 1),
#   ('plain', 1),
#   ('crime', 1),
#   ('ingredient', 1),
#   ('everywhere', 1),
#   ('evidence', 1),
#   ('publish', 1),
#   ('sight', 1)],
#  [('maga', 1), ('qanon', 1), ('corruption', 1), ('massive', 1)],
#  [('truthmatter', 1)],
#  [('time', 1), ('child', 1)],
#  [('sister', 1), ('soul', 1)],
#  [('fresh', 1), ('poppin', 1)],
#  [('grammar', 1), ('toaster', 1), ('careful', 1), ('gay', 1)],
#  [('vaccine', 2),
#   ('thing', 1),
#   ('concerned', 1),
#   ('deal', 1),
#   ('great', 1),
#   ('important', 1),
#   ('info', 1),
#   ('note', 1),
#   ('pre', 1),
#   ('presidency', 1)],
#  [('shot', 1), ('yrs', 1), ('child', 1)],
#  [('greatawakene', 1),
#   ('maga', 1),
#   ('wga', 1),
#   ('wwg', 1),
#   ('closerfamily', 1),
#   ('closermoment', 1),
#   ('closernation', 1)],
#  [('agree', 1), ('president', 1), ('note', 1)],
#  [('let', 1), ('keep', 1), ('disease', 1), ('country', 1), ('illegal', 1)],
#  [('doctor', 1), ('sure', 1), ('md', 1), ('medicine', 1), ('presidental', 1)],
#  [('doctor', 1),
#   ('fight', 1),
#   ('ball', 1),
#   ('access', 2),
#   ('brass', 1),
#   ('dream', 1),
#   ('mds', 1),
#   ('nature', 1),
#   ('something', 1),
#   ('stuff', 1)],
#  [('kid', 1),
#   ('vaccine', 1),
#   ('vaccination', 1),
#   ('care', 1),
#   ('state', 1),
#   ('study', 1),
#   ('research', 1),
#   ('believemother', 1),
#   ('bigpharmafraud', 1),
#   ('disable', 1),
#   ('ever', 1),
#   ('fakemeasle', 1),
#   ('industry', 1),
#   ('learntherisk', 1),
#   ('mandate', 1),
#   ('pharmaceutical', 1),
#   ('profit', 1),
#   ('sick', 1)],
#  [('autism', 1),
#   ('shot', 1),
#   ('potus', 1),
#   ('mmr', 1),
#   ('exactly', 1),
#   ('cousin', 1),
#   ('son', 1),
#   ('split', 1),
#   ('trip', 1),
#   ('verbal', 1),
#   ('wife', 1)],
#  [('time', 1),
#   ('give', 1),
#   ('tiny', 1),
#   ('frickin', 1),
#   ('geez', 1),
#   ('louise', 1),
#   ('nephew', 1)],
#  [('time', 1),
#   ('shot', 1),
#   ('spread', 1),
#   ('year', 1),
#   ('enough', 1),
#   ('mmr', 1),
#   ('research', 1),
#   ('long', 2),
#   ('base', 1),
#   ('recco', 1)],
#  [('back', 1), ('push', 1), ('demand', 1), ('dr', 1), ('separate', 1)],
#  [('week', 1)],
#  [('question', 1),
#   ('care', 1),
#   ('medical', 1),
#   ('something', 1),
#   ('block', 1),
#   ('charge', 1),
#   ('customer', 1),
#   ('mantra', 1),
#   ('patient', 1)],
#  [],
#  [],
#  [],
#  [('trump', 1),
#   ('anti', 1),
#   ('tweet', 1),
#   ('bambini', 1),
#   ('buonsenso', 1),
#   ('celebre', 1),
#   ('contrario', 1),
#   ('ddl', 1),
#   ('dosi', 1),
#   ('gli', 2),
#   ('lemblema', 1),
#   ('libertadiscelta', 1),
#   ('massicce', 1),
#   ('mondo', 1),
#   ('nel', 1),
#   ('novax', 1),
#   ('piccoli', 1),
#   ('piu', 1),
#   ('questo', 1),
#   ('scatti', 1),
#   ('sono', 2),
#   ('sparare', 1),
#   ('spargere', 1),
#   ('tempo', 1),
#   ('tutti', 1),
#   ('vaccini', 1),
#   ('vaccino', 1)],
#  [('novax', 1),
#   ('piu', 1),
#   ('capo', 1),
#   ('che', 1),
#   ('pericoloso', 1),
#   ('politico', 1),
#   ('sia', 1)],
#  [('gli', 2),
#   ('nel', 1),
#   ('piu', 1),
#   ('questo', 1),
#   ('sono', 1),
#   ('tempo', 1),
#   ('tutti', 1),
#   ('che', 2),
#   ('sia', 1),
#   ('altri', 1),
#   ('anche', 1),
#   ('capi', 1),
#   ('contro', 1),
#   ('dallelite', 1),
#   ('dara', 1),
#   ('degli', 1),
#   ('dei', 1),
#   ('dura', 1),
#   ('isolato', 1),
#   ('lucidi', 1),
#   ('lui', 1),
#   ('modi', 1),
#   ('ogni', 1),
#   ('pero', 1),
#   ('politici', 1),
#   ('popolo', 1),
#   ('pupazzi', 1),
#   ('quasi', 1),
#   ('ragione', 1),
#   ('rema', 1),
#   ('sostegno', 1),
#   ('spero', 1),
#   ('su', 2),
#   ('tema', 1),
#   ('temo', 1),
#   ('tempi', 1),
#   ('trova', 1),
#   ('tutto', 1),
#   ('ultimi', 1),
#   ('uno', 1),
#   ('utili', 1)],
#  [('caldo', 1), ('click', 1), ('sparisci', 1)],
#  [('kid', 1),
#   ('trump', 1),
#   ('pediatrician', 1),
#   ('medical', 1),
#   ('advice', 1),
#   ('ill', 1)],
#  [('people', 1),
#   ('address', 1),
#   ('bind', 1),
#   ('fact', 1),
#   ('hater', 1),
#   ('idiot', 1),
#   ('loser', 1),
#   ('vote', 1),
#   ('win', 1)],
#  [('talk', 1),
#   ('people', 1),
#   ('medical', 1),
#   ('advice', 1),
#   ('cruise', 1),
#   ('jenny', 1),
#   ('mccarthy', 1),
#   ('prefer', 1),
#   ('tom', 1)],
#  [('trump', 1),
#   ('anything', 1),
#   ('first', 1),
#   ('pre', 1),
#   ('medicine', 1),
#   ('comb', 1)],
#  [('ignorance', 1), ('smell', 1), ('sweet', 1), ('twattery', 1)],
#  [('time', 2), ('spread', 2), ('man', 1), ('disease', 1), ('insane', 1)],
#  [('mean', 1), ('really', 1), ('complete', 1), ('special', 1), ('tool', 1)],
#  [('trump', 1),
#   ('next', 1),
#   ('president', 1),
#   ('button', 1),
#   ('finger', 1),
#   ('maybe', 1),
#   ('regan', 1),
#   ('scarey', 1)],
#  [('vaccination', 1),
#   ('work', 1),
#   ('show', 1),
#   ('antivaxxer', 1),
#   ('classic', 1),
#   ('comeback', 1),
#   ('foggy', 1)],
#  [('indeed', 1)],
#  [('bloody', 1), ('hope', 1), ('terrify', 1)],
#  [('vaccine', 1), ('people', 1), ('actually', 1), ('protect', 1), ('ff', 1)],
#  [('really', 1),
#   ('antivaxxer', 1),
#   ('live', 1),
#   ('parallel', 1),
#   ('universe', 1)],
#  [('trump', 1), ('hear', 1), ('always', 1), ('great', 1)],
#  [('march', 1)],
#  [('september', 1)],
#  [('trump', 1), ('opinion', 1)],
#  [('vaccine', 1), ('autism', 1), ('doctor', 1), ('debunk', 1)],
#  [('ill', 1), ('mind', 1), ('physician', 1), ('trust', 1)],
#  [('hate', 1), ('true', 1)],
#  [('doctor', 1)],
#  [('watch', 1),
#   ('note', 1),
#   ('dignity', 1),
#   ('grace', 1),
#   ('obama', 1),
#   ('peotus', 1),
#   ('present', 1),
#   ('prestige', 1),
#   ('real', 1),
#   ('tv', 1)],
#  [('trump', 1), ('md', 1), ('doubt', 1), ('univ', 1)],
#  [('opinion', 1), ('informed', 1), ('medical', 1), ('guess', 1), ('serve', 1)],
#  [('mature', 1)],
#  [('hate', 1), ('sin', 1), ('sinner', 1)],
#  [('trump', 1),
#   ('child', 1),
#   ('tiny', 1),
#   ('oppose', 1),
#   ('everything', 1),
#   ('size', 1)],
#  [('talk', 1),
#   ('vaccination', 1),
#   ('evidence', 1),
#   ('hater', 1),
#   ('loser', 1),
#   ('brake', 1)],
#  [('doctor', 1), ('wait', 1)],
#  [('maybe', 1), ('chair', 1), ('co', 1), ('hell', 1), ('name', 1)],
#  [('anti', 2), ('believe', 1), ('today', 1), ('american', 1), ('russian', 1)],
#  [('man', 1), ('orange', 1)],
#  [('siren', 1)],
#  [('vaccine', 2),
#   ('trump', 2),
#   ('ask', 1),
#   ('president', 1),
#   ('jr', 1),
#   ('rfk', 1),
#   ('doubt', 1),
#   ('chair', 1),
#   ('commission', 1),
#   ('current', 1),
#   ('elect', 1),
#   ('pic_twitter_com', 1),
#   ('policy', 1),
#   ('vncdsueugi', 1)],
#  [('vaccine', 1),
#   ('trump', 1),
#   ('tweet', 1),
#   ('bzzpbyhmoe', 1),
#   ('yearspic', 1)],
#  [('statement', 1),
#   ('uninformed', 2),
#   ('ignorance', 1),
#   ('educate', 1),
#   ('health', 2),
#   ('non', 1),
#   ('ppl', 1),
#   ('relate', 1),
#   ('uneducated', 1)],
#  [('still', 1), ('buffoon', 1), ('comprehend', 1), ('wh', 1)],
#  [('medical', 1), ('school', 1), ('attend', 1)],
#  [('time', 2), ('trump', 1), ('doctor', 1), ('play', 1), ('twitter', 1)],
#  [('look', 1), ('object', 1), ('quick', 1), ('shiny', 1)],
#  [('explore', 1)],
#  [('vaccine', 1),
#   ('opinion', 1),
#   ('medical', 1),
#   ('schedule', 1),
#   ('degree', 1),
#   ('forget', 1),
#   ('pediatric', 1),
#   ('qualifie', 1)],
#  [('child', 1),
#   ('love', 1),
#   ('tiny', 1),
#   ('ppl', 1),
#   ('uneducated', 1),
#   ('due', 1),
#   ('primal', 1),
#   ('resonate', 1),
#   ('respect', 1),
#   ('stunning', 1),
#   ('vocabulary', 1)],
#  [('march', 1)],
#  [('kid', 1), ('vaccine', 1), ('md', 1)],
#  [('thing', 1), ('least', 1)],
#  [('people', 1),
#   ('look', 1),
#   ('injection', 1),
#   ('massive', 1),
#   ('affect', 1),
#   ('trune', 1)],
#  [('putin', 1), ('stooge', 1)],
#  [('trump', 1),
#   ('medical', 1),
#   ('little', 1),
#   ('advice', 1),
#   ('blow', 1),
#   ('dispense', 1),
#   ('hard', 1),
#   ('pathetic', 1)],
#  [('trump', 1), ('ignorance', 1), ('awhile', 1)],
#  [('doctor', 1), ('sad', 1)],
#  [('trump', 1),
#   ('old', 1),
#   ('tweet', 1),
#   ('back', 1),
#   ('sad', 1),
#   ('day', 1),
#   ('discover', 1),
#   ('team', 1)],
#  [('medical', 1), ('expert', 1)],
#  [('trump', 1), ('md', 1), ('donald', 1)],
#  [('tweet', 1), ('wrong', 1), ('truth', 1), ('tho', 1)],
#  [('opinion', 1),
#   ('evidence', 1),
#   ('scientific', 1),
#   ('spout', 1),
#   ('worthless', 1)],
#  [('time', 1),
#   ('visit', 1),
#   ('care', 1),
#   ('apparently', 1),
#   ('give', 1),
#   ('well', 1),
#   ('ever', 1),
#   ('children', 1),
#   ('involve', 1)],
#  [('glad', 1),
#   ('peotus', 1),
#   ('health', 1),
#   ('complex', 1),
#   ('knowledge', 1),
#   ('matter', 1),
#   ('refined', 1)],
#  [('vaccine', 1),
#   ('autism', 1),
#   ('autistic', 1),
#   ('disease', 1),
#   ('safe', 1),
#   ('son', 1),
#   ('communicable', 1),
#   ('sigh', 1)],
#  [('trump', 1), ('medical', 1), ('degree', 1), ('undoubtedly', 1)],
#  [('vaccine', 1),
#   ('trump', 1),
#   ('autistic', 1),
#   ('safe', 1),
#   ('son', 2),
#   ('maybe', 1),
#   ('imperfect', 1),
#   ('perceive', 1),
#   ('place', 1),
#   ('spectrum', 1)],
#  [('alex', 1), ('appoint', 1), ('jone', 1), ('omg', 1)],
#  [('pic_twitter_com', 1), ('amynnc', 1)],
#  [('autism', 1),
#   ('omg', 1),
#   ('absolute', 1),
#   ('insanity', 1),
#   ('mom', 1),
#   ('twice', 1)],
#  [],
#  [('kid', 1), ('little', 1), ('suffer', 1), ('outreach', 1)],
#  [('wrong', 1), ('research', 1), ('paper', 1), ('read', 1)],
#  [],
#  [('first', 1), ('experience', 1), ('hand', 1)],
#  [('autism', 1), ('jenny', 1), ('mccarthy', 1), ('secretary', 1)],
#  [('autism', 1),
#   ('vaccination', 1),
#   ('medical', 1),
#   ('ago', 1),
#   ('cause', 1),
#   ('allegation', 1),
#   ('board', 1),
#   ('month', 1),
#   ('refute', 1)],
#  [('well', 1), ('idiot', 1), ('tinyman', 1), ('traitor', 1)],
#  [('trump', 1),
#   ('feel', 1),
#   ('show', 1),
#   ('ignorance', 1),
#   ('bachmann', 1),
#   ('depth', 1),
#   ('michelle', 1),
#   ('must', 1),
#   ('vindicate', 1)],
#  [('keep', 1),
#   ('top', 1),
#   ('particular', 1),
#   ('son', 1),
#   ('spectrum', 1),
#   ('bradd', 1),
#   ('expose', 1),
#   ('favor', 1),
#   ('hypocrisy', 1),
#   ('theresistance', 1)],
#  [('wait', 1), ('tell', 1), ('ricky', 1), ('ross', 1), ('somebody', 1)],
#  [('child', 1), ('probably', 1), ('barron', 1), ('sadly', 1)],
#  [('thing', 1),
#   ('stagger', 1),
#   ('ignorance', 1),
#   ('awful', 1),
#   ('teach', 1),
#   ('truly', 1)],
#  [('vaccine', 1),
#   ('obviously', 1),
#   ('burn', 1),
#   ('fake', 1),
#   ('landing', 1),
#   ('moonn', 1),
#   ('popcorn', 1)],
#  [('away', 1),
#   ('today', 1),
#   ('russian', 1),
#   ('attention', 1),
#   ('deflect', 1),
#   ('hacking', 1),
#   ('hearing', 1),
#   ('news', 1)],
#  [('decision', 1), ('shannon', 1), ('wise', 1)],
#  [('glad', 1), ('understand', 1), ('ppl', 1), ('wish', 1)],
#  [('trump', 1),
#   ('year', 1),
#   ('polio', 1),
#   ('shit', 1),
#   ('load', 1),
#   ('healthcare', 1)],
#  [('trump', 1),
#   ('president', 1),
#   ('attribute', 1),
#   ('conspiracy', 1),
#   ('inclination', 1),
#   ('natural', 1),
#   ('theory', 1)],
#  [('die', 2),
#   ('well', 1),
#   ('disease', 1),
#   ('ago', 1),
#   ('decade', 1),
#   ('eradicate', 1),
#   ('nuclear', 1),
#   ('war', 1)],
#  [('disease', 1),
#   ('ready', 1),
#   ('stream', 1),
#   ('childhood', 1),
#   ('mump', 1),
#   ('outbreak', 1)],
#  [('medical', 1),
#   ('jr', 1),
#   ('rfk', 1),
#   ('american', 2),
#   ('pediatric', 1),
#   ('academy', 1),
#   ('association', 1),
#   ('cdc', 1),
#   ('djt', 1),
#   ('usurp', 1)],
#  [('horrify', 1)],
#  [('still', 1), ('change', 1), ('climate', 1), ('hoax', 1)],
#  [('peotus', 1), ('experience', 1), ('issue', 1), ('personal', 1)],
#  [('anti', 1),
#   ('back', 1),
#   ('vax', 1),
#   ('live', 1),
#   ('health', 1),
#   ('decade', 1),
#   ('endanger', 1),
#   ('global', 1),
#   ('million', 1),
#   ('position', 1),
#   ('set', 1)],
#  [('vaccine', 1),
#   ('interesting', 1),
#   ('anti', 1),
#   ('medical', 1),
#   ('share', 1),
#   ('understand', 1),
#   ('safety', 1),
#   ('non', 1),
#   ('bs', 1),
#   ('professional', 1),
#   ('scientist', 1)],
#  [('thing', 1), ('government', 1), ('great', 1), ('trust', 1)],
#  [('indeed', 1)],
#  [('pic_twitter_com', 1), ('jowmakhofk', 1)],
#  [('loud', 1)],
#  [('fg', 1), ('lv', 1), ('tufo', 1)],
#  [('son', 1),
#   ('position', 1),
#   ('adopt', 1),
#   ('observe', 1),
#   ('possible', 1),
#   ('situation', 1)],
#  [('cabinet', 1), ('hillarys', 1)],
#  [],
#  [('vaccine', 1),
#   ('safety', 1),
#   ('efficacy', 1),
#   ('prove', 2),
#   ('vaccinated', 1)],
#  [('pay', 1),
#   ('year', 1),
#   ('clearly', 1),
#   ('read', 1),
#   ('attention', 1),
#   ('lunacy', 1),
#   ('myriad', 1),
#   ('tweets', 1)],
#  [('scientist', 1), ('actual', 1)],
#  [('election', 1)],
#  [('care', 1),
#   ('story', 1),
#   ('friend', 1),
#   ('son', 1),
#   ('bullshit', 1),
#   ('family', 1)],
#  [('much', 1), ('change', 1), ('bother', 1), ('dad', 1), ('diaper', 1)],
#  [('careful', 1), ('edge', 1), ('flat', 1), ('world', 1)],
#  [('mother', 1),
#   ('believe', 1),
#   ('obama', 1),
#   ('must', 1),
#   ('birther', 1),
#   ('critical', 1),
#   ('kenya', 1),
#   ('possibly', 1),
#   ('skill', 1),
#   ('teenage', 1),
#   ('thinking', 1),
#   ('vaxer', 1)],
#  [('vaccine', 1),
#   ('trump', 1),
#   ('tweet', 1),
#   ('year', 1),
#   ('omg', 1),
#   ('hu', 1),
#   ('wbj', 1)],
#  [('jakhnonulv', 1), ('reasonablepic', 1)],
#  [('never', 1), ('sure', 1), ('injury', 1), ('head', 1), ('close', 1)],
#  [('notice', 1), ('suppose', 1)],
#  [('anyone', 1), ('trump', 1), ('hear', 1), ('else', 1), ('supporter', 1)],
#  [('trump', 1), ('talk', 1), ('exactly', 1), ('great', 1), ('job', 1)],
#  [('measle', 1), ('great', 1)],
#  [('vaccine', 1),
#   ('already', 1),
#   ('rfk', 1),
#   ('idiot', 1),
#   ('jenny', 1),
#   ('scientific', 1),
#   ('scientist', 1),
#   ('integrity', 1),
#   ('join', 1),
#   ('mcarthy', 1),
#   ('regard', 1)],
#  [('vaccine', 1),
#   ('trump', 1),
#   ('autism', 1),
#   ('home', 1),
#   ('deep', 1),
#   ('issue', 1),
#   ('close', 1)],
#  [('lol', 1), ('president', 1), ('elect', 1), ('troll', 1), ('twitt', 1)],
#  [('mean', 1),
#   ('vaccine', 1),
#   ('policy', 1),
#   ('fda', 1),
#   ('grief', 1),
#   ('idiocy', 1),
#   ('reg', 1),
#   ('rule', 1)],
#  [('grave', 1), ('ted', 1), ('turn', 1)],
#  [],
#  [('vaccine', 1),
#   ('autism', 1),
#   ('study', 1),
#   ('immune', 1),
#   ('eg', 1),
#   ('latent', 1),
#   ('stress', 1),
#   ('trigger', 1)],
#  [('kid', 1),
#   ('let', 1),
#   ('kill', 1),
#   ('idiot', 1),
#   ('affect', 1),
#   ('dumbass', 1),
#   ('fuck', 1),
#   ('innocent', 1)],
#  [('vaccine', 1), ('trump', 1), ('pox', 1)],
#  [('kid', 1), ('people', 1), ('care', 1), ('angry', 1), ('legitimately', 1)],
#  [('kid', 1),
#   ('anyone', 1),
#   ('time', 1),
#   ('vaccinate', 1),
#   ('trump', 1),
#   ('ask', 1),
#   ('bother', 1),
#   ('grandkid', 1),
#   ('lie', 1)],
#  [('really', 1),
#   ('science', 1),
#   ('maybe', 1),
#   ('encumbered', 1),
#   ('ideology', 1),
#   ('less', 1),
#   ('obligate', 1),
#   ('obligation', 1),
#   ('remain', 1)],
#  [('ask', 1),
#   ('question', 1),
#   ('someone', 1),
#   ('physician', 1),
#   ('academy', 1),
#   ('scientist', 1),
#   ('amer', 1),
#   ('cd', 1),
#   ('nih', 1),
#   ('ped', 1),
#   ('researcher', 1)],
#  [('news', 1), ('horrible', 1)],
#  [('kid', 1),
#   ('death', 1),
#   ('commission', 1),
#   ('actual', 1),
#   ('call', 1),
#   ('panel', 1)],
#  [('leave', 1), ('beta', 1), ('cuck', 1), ('libtard', 1)],
#  [('vaccine', 1),
#   ('general', 1),
#   ('cos', 1),
#   ('dismiss', 1),
#   ('luddite', 1),
#   ('pharma', 1),
#   ('rejection', 1),
#   ('treat', 1)],
#  [('trump', 1), ('never', 1), ('tell', 1), ('barron', 1), ('poor', 1)],
#  [],
#  [('man', 2),
#   ('president', 1),
#   ('new', 1),
#   ('day', 1),
#   ('gut', 1),
#   ('nightmarish', 1),
#   ('punch', 1)],
#  [('rumor', 1),
#   ('tell', 1),
#   ('reason', 1),
#   ('son', 1),
#   ('true', 1),
#   ('hard', 1),
#   ('insanity', 1),
#   ('environment', 1)],
#  [('actuale', 1),
#   ('antojadizos', 1),
#   ('claro', 1),
#   ('esquema', 1),
#   ('fueron', 1),
#   ('invento', 1),
#   ('los', 1),
#   ('porque', 1),
#   ('vacunacion', 1)],
#  [('doctor', 1), ('opinion', 1), ('medical', 1), ('qualify', 1)],
#  [('insanity', 1)],
#  [('fackts', 1)],
#  [('trump', 1), ('end', 1), ('deep', 1)],
#  [('actually', 1), ('agree', 1), ('scary', 1), ('something', 1), ('omg', 1)],
#  [('medical', 1), ('school', 1), ('graduate', 1)],
#  [],
#  [('child', 1), ('space', 1)],
#  [('trump', 1),
#   ('today', 1),
#   ('maybe', 1),
#   ('bullying', 1),
#   ('lead', 1),
#   ('short', 1),
#   ('someday', 1),
#   ('term', 1),
#   ('transright', 1),
#   ('violence', 1)],
#  [('kid', 1),
#   ('vaccinate', 1),
#   ('people', 1),
#   ('today', 1),
#   ('matter', 1),
#   ('less', 1)],
#  [('mean', 1),
#   ('measle', 1),
#   ('happen', 1),
#   ('back', 1),
#   ('disease', 1),
#   ('long', 1),
#   ('eliminate', 1),
#   ('virtually', 1)],
#  [('never', 1),
#   ('give', 1),
#   ('bad', 1),
#   ('sense', 1),
#   ('reaction', 1),
#   ('common', 1),
#   ('mom', 1),
#   ('dad', 1),
#   ('god', 1)],
#  [],
#  [('tweet', 1), ('format', 1), ('start', 1)],
#  [('cosign', 1)],
#  [('autism', 1), ('vaxxe', 1), ('oneissue', 1), ('usa', 1)],
#  [('autism', 1), ('vaxxe', 1), ('oneissue', 1), ('usa', 1)],
#  [('wait', 1), ('inject', 1), ('minute', 1), ('straight', 1)],
#  [('next', 1), ('general', 1), ('jenny', 1), ('mccarthy', 1), ('surgeon', 1)],
#  [('trump', 1),
#   ('give', 1),
#   ('tweet', 1),
#   ('pretty', 1),
#   ('maga', 1),
#   ('head', 1),
#   ('knowledge', 1),
#   ('conspiracy', 1),
#   ('democrat', 1),
#   ('direction', 1),
#   ('leap', 1),
#   ('minded', 1),
#   ('pedophile', 1),
#   ('secret', 1),
#   ('send', 1),
#   ('wonder', 1)],
#  [('elect', 1),
#   ('due', 1),
#   ('healthcare', 1),
#   ('proposal', 1),
#   ('sophisticated', 1)],
#  [('insane', 1),
#   ('live', 1),
#   ('real', 1),
#   ('world', 1),
#   ('afaict', 1),
#   ('belief', 1),
#   ('boil', 1),
#   ('core', 1),
#   ('fantasy', 1),
#   ('folk', 1),
#   ('hurt', 1),
#   ('lib', 1),
#   ('nothing', 1),
#   ('offend', 1),
#   ('online', 1),
#   ('republican', 1),
#   ('route', 1),
#   ('suspect', 1)],
#  [('attack', 1), ('depend', 1), ('host', 1), ('shark', 1)],
#  [('single', 1),
#   ('love', 1),
#   ('health', 1),
#   ('stunning', 1),
#   ('children', 1),
#   ('folk', 1),
#   ('devoted', 1),
#   ('intellect', 1),
#   ('mtvs', 1)],
#  [('charlie', 1), ('rob', 1), ('schneider', 1), ('sheen', 1)],
#  [('really', 1),
#   ('man', 1),
#   ('way', 1),
#   ('gut', 1),
#   ('imagery', 1),
#   ('impressively', 1),
#   ('instinctual', 1),
#   ('level', 1),
#   ('poetic', 1),
#   ('reptilian', 1),
#   ('terrifying', 1),
#   ('word', 1)]]

# %%
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=4, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=10,
                                           passes=10,
                                           alpha='symmetric',
                                           iterations=100,
                                           per_word_topics=True)

# %%
print(lda_model.print_topics())
# Out:
# [(0,
#   '0.025*"man" + 0.021*"health" + 0.020*"gut" + 0.019*"autism" + 0.019*"love" '
#   '+ 0.018*"stunning" + 0.018*"way" + 0.018*"sheen" + 0.018*"charlie" + '
#   '0.018*"schneider"'),
#  (1,
#   '0.015*"today" + 0.015*"never" + 0.013*"maybe" + 0.012*"president" + '
#   '0.012*"tell" + 0.012*"child" + 0.011*"head" + 0.011*"back" + 0.011*"omg" + '
#   '0.010*"mean"'),
#  (2,
#   '0.032*"folk" + 0.030*"really" + 0.026*"children" + 0.025*"kid" + '
#   '0.014*"give" + 0.011*"vaccine" + 0.010*"vaccinate" + 0.010*"live" + '
#   '0.010*"doctor" + 0.010*"time"'),
#  (3,
#   '0.060*"trump" + 0.031*"vaccine" + 0.019*"tweet" + 0.012*"people" + '
#   '0.011*"general" + 0.010*"elect" + 0.009*"great" + 0.009*"wait" + '
#   '0.009*"deep" + 0.009*"measle"')]

# %%
#how good a given topic model is = fazer varios modelos com n topicos e pegar a maior coherence score
# Compute Perplexity
print('\nPerplexity: ', lda_model.log_perplexity(corpus))  # a measure of how good the model is. lower the better.

# Compute Coherence Score
coherence_model_lda = CoherenceModel(model=lda_model, texts=data_ready, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score: ', coherence_lda)
# Out:
# Perplexity:  -8.189558878628953
#
# Coherence Score:  0.5801914507623672

# %%
def format_topics_sentences(ldamodel=None, corpus=corpus, texts=data):
    # Init output
    sent_topics_df = pd.DataFrame()

    # Get main topic in each document
    for i, row_list in enumerate(ldamodel[corpus]):
        row = row_list[0] if ldamodel.per_word_topics else row_list            
        # print(row)
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

    # Add original text to the end of the output
    contents = pd.Series(texts)
    sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
    return(sent_topics_df)

# %%
df_topic_sents_keywords = format_topics_sentences(ldamodel=lda_model, corpus=corpus, texts=data_ready)

# %%
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']
df_dominant_topic.head(10)
# Out:
#    Document_No  Dominant_Topic  Topic_Perc_Contrib  \
# 0            0             2.0              0.8070
# 1            1             1.0              0.4527
# 2            2             2.0              0.8726
# 3            3             3.0              0.8463
# 4            4             0.0              0.7520
# 5            5             3.0              0.5601
# 6            6             0.0              0.2500
# 7            7             3.0              0.8236
# 8            8             1.0              0.7392
# 9            9             1.0              0.6061
#
#                                             Keywords  \
# 0  folk, really, children, kid, give, vaccine, va...
# 1  today, never, maybe, president, tell, child, h...
# 2  folk, really, children, kid, give, vaccine, va...
# 3  trump, vaccine, tweet, people, general, elect,...
# 4  man, health, gut, autism, love, stunning, way,...
# 5  trump, vaccine, tweet, people, general, elect,...
# 6  man, health, gut, autism, love, stunning, way,...
# 7  trump, vaccine, tweet, people, general, elect,...
# 8  today, never, maybe, president, tell, child, h...
# 9  today, never, maybe, president, tell, child, h...
#
#                                                 Text
# 0                                  [cept, kid, cage]
# 1                             [anyone, figure, mean]
# 2         [kid, vaccinate, literally, vaccine, time]
# 3                 [trump, nuance, approach, vaccine]
# 4  [begin, campaign, talk, rumor, circulate, baro...
# 5                         [interesting, never, hear]
# 6                                                 []
# 7  [people, ask, question, already, answer, anti,...
# 8                                 [oldie, muckenfuk]
# 9                                           [normal]

# %%
pd.options.display.max_colwidth = 100

# %%
sent_topics_sorteddf_mallet = pd.DataFrame()
sent_topics_outdf_grpd = df_topic_sents_keywords.groupby('Dominant_Topic')
for i, grp in sent_topics_outdf_grpd:
    sent_topics_sorteddf_mallet = pd.concat([sent_topics_sorteddf_mallet, 
                                             grp.sort_values(['Perc_Contribution'], ascending=False).head(1)], 
                                            axis=0)

# %%
# Reset Index    
sent_topics_sorteddf_mallet.reset_index(drop=True, inplace=True)

# Format
sent_topics_sorteddf_mallet.columns = ['Topic_Num', "Topic_Perc_Contrib", "Keywords", "Representative Text"]

# Show
sent_topics_sorteddf_mallet.head(10)
# Out:
#    Topic_Num  Topic_Perc_Contrib  \
# 0        0.0              0.9831
# 1        1.0              0.9423
# 2        2.0              0.9577
# 3        3.0              0.9747
#
#                                                                     Keywords  \
# 0   man, health, gut, autism, love, stunning, way, sheen, charlie, schneider
# 1         today, never, maybe, president, tell, child, head, back, omg, mean
# 2  folk, really, children, kid, give, vaccine, vaccinate, live, doctor, time
# 3   trump, vaccine, tweet, people, general, elect, great, wait, deep, measle
#
#                                                                                    Representative Text
# 0  [temo, che, sia, uno, dei, piu, lucidi, capi, politici, degli, ultimi, tempi, questo, su, quasi,...
# 1  [must, critical, thinking, skill, vaxer, birther, possibly, believe, obama, teenage, mother, kenya]
# 2  [obviously, parent, visit, pediatrician, single, immunization, pay, doctor, visit, vaccine, work...
# 3  [tutti, gli, sono, anti, vaccino, sono, contrario, sparare, dosi, massicce, bambini, piccoli, sp...

# %%
# Number of Documents for Each Topic
topic_counts = df_topic_sents_keywords['Dominant_Topic'].value_counts()

# Percentage of Documents for Each Topic
topic_contribution = round(topic_counts/topic_counts.sum(), 4)

# Topic Number and Keywords
topic_num_keywords = df_topic_sents_keywords[['Dominant_Topic', 'Topic_Keywords']]

# Concatenate Column wise
df_dominant_topics = pd.concat([topic_num_keywords, topic_counts, topic_contribution], axis=1)

# Change Column names
df_dominant_topics.columns = ['Dominant_Topic', 'Topic_Keywords', 'Num_Documents', 'Perc_Documents']

# Show
df_dominant_topics
# Out:
#        Dominant_Topic  \
# 0.0               2.0
# 1.0               1.0
# 2.0               2.0
# 3.0               3.0
# 4.0               0.0
# ...               ...
# 288.0             2.0
# 289.0             2.0
# 290.0             0.0
# 291.0             0.0
# 292.0             0.0
#
#                                                                   Topic_Keywords  \
# 0.0    folk, really, children, kid, give, vaccine, vaccinate, live, doctor, time
# 1.0           today, never, maybe, president, tell, child, head, back, omg, mean
# 2.0    folk, really, children, kid, give, vaccine, vaccinate, live, doctor, time
# 3.0     trump, vaccine, tweet, people, general, elect, great, wait, deep, measle
# 4.0     man, health, gut, autism, love, stunning, way, sheen, charlie, schneider
# ...                                                                          ...
# 288.0  folk, really, children, kid, give, vaccine, vaccinate, live, doctor, time
# 289.0  folk, really, children, kid, give, vaccine, vaccinate, live, doctor, time
# 290.0   man, health, gut, autism, love, stunning, way, sheen, charlie, schneider
# 291.0   man, health, gut, autism, love, stunning, way, sheen, charlie, schneider
# 292.0   man, health, gut, autism, love, stunning, way, sheen, charlie, schneider
#
#        Num_Documents  Perc_Documents
# 0.0             75.0          0.2560
# 1.0             82.0          0.2799
# 2.0             67.0          0.2287
# 3.0             69.0          0.2355
# 4.0              NaN             NaN
# ...              ...             ...
# 288.0            NaN             NaN
# 289.0            NaN             NaN
# 290.0            NaN             NaN
# 291.0            NaN             NaN
# 292.0            NaN             NaN
#
# [293 rows x 4 columns]

# %%
doc_lens = [len(d) for d in df_dominant_topic.Text]

# Plot
plt.figure(figsize=(16,7), dpi=160)
plt.hist(doc_lens, bins = 100, color='navy')
#plt.text(750, 100, "Mean   : " + str(round(np.mean(doc_lens))))
#plt.text(750,  90, "Median : " + str(round(np.median(doc_lens))))
#plt.text(750,  80, "Stdev   : " + str(round(np.std(doc_lens))))
#plt.text(750,  70, "1%ile    : " + str(round(np.quantile(doc_lens, q=0.01))))
#plt.text(750,  60, "99%ile  : " + str(round(np.quantile(doc_lens, q=0.99))))

plt.gca().set(xlim=(0, 100), ylabel='Número de documentos', xlabel='Contagem de palavras do documento')
plt.tick_params(size=16)
plt.xticks(np.linspace(0,100,9))
plt.title('Distribuição de número de palavras por tweet', fontdict=dict(size=22))
plt.show()

# %%
cols = [color for name, color in mcolors.TABLEAU_COLORS.items()]  # more colors: 'mcolors.XKCD_COLORS'

fig, axes = plt.subplots(2,2,figsize=(16,14), dpi=160, sharex=True, sharey=True)

for i, ax in enumerate(axes.flatten()):    
    df_dominant_topic_sub = df_dominant_topic.loc[df_dominant_topic.Dominant_Topic == i, :]
    doc_lens = [len(d) for d in df_dominant_topic_sub.Text]
    ax.hist(doc_lens, bins = 1000, color=cols[i])
    ax.tick_params(axis='y', labelcolor=cols[i], color=cols[i])
    sns.kdeplot(doc_lens, color="black", shade=False, ax=ax.twinx())
    ax.set(xlim=(0, 100), xlabel='Contagem de palavras do documento')
    ax.set_ylabel('Número de documentos', color=cols[i])
    ax.set_title('Topic: '+str(i), fontdict=dict(size=16, color=cols[i]))

fig.tight_layout()
fig.subplots_adjust(top=0.90)
plt.xticks(np.linspace(0,100,9))
fig.suptitle('Distribuição de número de palavras por tweet separado por tópicos', fontsize=22)
plt.show()

# %%
cols = [color for name, color in mcolors.TABLEAU_COLORS.items()]  # more colors: 'mcolors.XKCD_COLORS'

cloud = WordCloud(stopwords=stop_words,
                  background_color='white',
                  width=2500,
                  height=1800,
                  max_words=10,
                  colormap='tab10',
                  color_func=lambda *args, **kwargs: cols[i],
                  prefer_horizontal=1.0)

topics = lda_model.show_topics(formatted=False)

fig, axes = plt.subplots(2, 2, figsize=(10,10), sharex=True, sharey=True)

for i, ax in enumerate(axes.flatten()):
    fig.add_subplot(ax)
    topic_words = dict(topics[i][1])
    cloud.generate_from_frequencies(topic_words, max_font_size=300)
    plt.gca().imshow(cloud)
    plt.gca().set_title('Topic ' + str(i), fontdict=dict(size=16))
    plt.gca().axis('off')

#tamanho das palavras proporcional ao peso
plt.subplots_adjust(wspace=0, hspace=0)
plt.axis('off')
plt.margins(x=0, y=0)
plt.tight_layout()
plt.show()

# %%
topics = lda_model.show_topics(formatted=False)
data_flat = [w for w_list in data_ready for w in w_list]
counter = Counter(data_flat)

out = []
for i, topic in topics:
    for word, weight in topic:
        out.append([word, i , weight, counter[word]])

df = pd.DataFrame(out, columns=['word', 'topic_id', 'importance', 'word_count'])        

# Plot Word Count and Weights of Topic Keywords
fig, axes = plt.subplots(2, 2, figsize=(16,10), sharey=True, dpi=160)
cols = [color for name, color in mcolors.TABLEAU_COLORS.items()]
for i, ax in enumerate(axes.flatten()):
    ax.bar(x='word', height="word_count", data=df.loc[df.topic_id==i, :], color=cols[i], width=0.5, alpha=0.3, label='Contagem de palavras')
    ax_twin = ax.twinx()
    ax_twin.bar(x='word', height="importance", data=df.loc[df.topic_id==i, :], color=cols[i], width=0.2, label='Pesos')
    ax.set_ylabel('Contagem de palavras', color=cols[i])
    ax_twin.set_ylim(0, 0.030); ax.set_ylim(0, 3500)
    ax.set_title('Topic: ' + str(i), color=cols[i], fontsize=16)
    ax.tick_params(axis='y', left=False)
    ax.set_xticklabels(df.loc[df.topic_id==i, 'word'], rotation=30, horizontalalignment= 'right')
    ax.legend(loc='upper left'); ax_twin.legend(loc='upper right')
#palavras com o a frequencia maior q o peso ou palavras q aparecem em varios topicos podem indicar possíveis stop words
fig.tight_layout(w_pad=2)    
fig.suptitle('Contagem de palavras e importância de palavras-chave dos tópicos', fontsize=22, y=1.05)    
plt.show()

# %%
sentences_chart(lda_model, corpus)

# %%
dominant_topics, topic_percentages = topics_per_document(model=lda_model, corpus=corpus, end=-1)            

# Distribution of Dominant Topics in Each Document
df = pd.DataFrame(dominant_topics, columns=['Document_Id', 'Dominant_Topic'])
dominant_topic_in_each_doc = df.groupby('Dominant_Topic').size()
df_dominant_topic_in_each_doc = dominant_topic_in_each_doc.to_frame(name='count').reset_index()

# Total Topic Distribution by actual weight
topic_weightage_by_doc = pd.DataFrame([dict(t) for t in topic_percentages])
df_topic_weightage_by_doc = topic_weightage_by_doc.sum().to_frame(name='count').reset_index()

# Top 3 Keywords for each Topic
topic_top3words = [(i, topic) for i, topics in lda_model.show_topics(formatted=False) 
                                 for j, (topic, wt) in enumerate(topics) if j < 3]

df_top3words_stacked = pd.DataFrame(topic_top3words, columns=['topic_id', 'words'])
df_top3words = df_top3words_stacked.groupby('topic_id').agg(', \n'.join)
df_top3words.reset_index(level=0,inplace=True)

# %%
# Plot
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4), dpi=120, sharey=True)

# Topic Distribution by Dominant Topics
ax1.bar(x='Dominant_Topic', height='count', data=df_dominant_topic_in_each_doc, width=.5, color='firebrick')
ax1.set_xticks(range(df_dominant_topic_in_each_doc.Dominant_Topic.unique().__len__()))
tick_formatter = FuncFormatter(lambda x, pos: 'Topic ' + str(x)+ '\n' + df_top3words.loc[df_top3words.topic_id==x, 'words'].values[0])
ax1.xaxis.set_major_formatter(tick_formatter)
ax1.set_title('Number of Documents by Dominant Topic', fontdict=dict(size=10))
ax1.set_ylabel('Number of Documents')
ax1.set_ylim(0, 1000)

# Topic Distribution by Topic Weights
ax2.bar(x='index', height='count', data=df_topic_weightage_by_doc, width=.5, color='steelblue')
ax2.set_xticks(range(df_topic_weightage_by_doc.index.unique().__len__()))
ax2.xaxis.set_major_formatter(tick_formatter)
ax2.set_title('Number of Documents by Topic Weightage', fontdict=dict(size=10))

plt.show()

# %%
# Get topic weights
topic_weights = []
for i, row_list in enumerate(lda_model[corpus]):
    topic_weights.append([w for i, w in row_list[0]])

# Array of topic weights    
arr = pd.DataFrame(topic_weights).fillna(0).values

# Keep the well separated points (optional)
arr = arr[np.amax(arr, axis=1) > 0.35]

# Dominant topic number in each doc
topic_num = np.argmax(arr, axis=1)

# tSNE Dimension Reduction
tsne_model = TSNE(n_components=2, verbose=1, random_state=0, angle=.99, init='pca')
tsne_lda = tsne_model.fit_transform(arr)

# Plot the Topic Clusters using Bokeh
output_notebook()
n_topics = 4
mycolors = np.array([color for name, color in mcolors.TABLEAU_COLORS.items()])
plot = figure(title="t-SNE Clustering of {} LDA Topics".format(n_topics), 
              plot_width=900, plot_height=700)
plot.scatter(x=tsne_lda[:,0], y=tsne_lda[:,1], color=mycolors[topic_num])
show(plot)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 271 samples in 0.000s...
# [t-SNE] Computed neighbors for 271 samples in 0.016s...
# [t-SNE] Computed conditional probabilities for sample 271 / 271
# [t-SNE] Mean sigma: 0.114880
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 52.035896
# [t-SNE] KL divergence after 950 iterations: 0.151345
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1097">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="661a028d-a00c-41a9-89e0-cb0febf3ce5e" data-root-id="1098"></div>

# %%
'''Each bubble on the left-hand side plot represents a topic. The larger the bubble, the more prevalent is that topic.

A good topic model will have fairly big, non-overlapping bubbles scattered throughout the chart instead of being clustered in one quadrant.

A model with too many topics, will typically have many overlaps, small sized bubbles clustered in one region of the chart.

The words and bars on the right-hand side will update. These words are the salient keywords that form the selected topic.'''
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(lda_model, corpus, dictionary=lda_model.id2word)
vis
# Out:
# c:\users\meomi\appdata\local\programs\python\python37\lib\site-packages\pyLDAvis\_prepare.py:257: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   return pd.concat([default_term_info] + list(topic_dfs))
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 3     -0.103368 -0.123609       1        1  28.869036
# 2     -0.027674  0.129914       2        1  25.776789
# 0      0.209829 -0.033535       3        1  23.741146
# 1     -0.078786  0.027230       4        1  21.613029, topic_info=    Category      Freq        Term      Total  loglift  logprob
# 12   Default  30.00000       trump  30.000000  30.0000  30.0000
# 968  Default  15.00000        folk  15.000000  29.0000  29.0000
# 77   Default  14.00000      really  14.000000  28.0000  28.0000
# 2    Default  11.00000         kid  11.000000  27.0000  27.0000
# 728  Default  12.00000    children  12.000000  26.0000  26.0000
# ..       ...       ...         ...        ...      ...      ...
# 937   Topic4   2.18015       short   2.930301   1.2362  -5.1612
# 936   Topic4   2.18015        lead   2.930301   1.2362  -5.1612
# 935   Topic4   2.18015    bullying   2.930301   1.2362  -5.1612
# 940   Topic4   2.18015  transright   2.930301   1.2362  -5.1612
# 941   Topic4   2.18015    violence   2.930301   1.2362  -5.1612
#
# [181 rows x 6 columns], token_table=      Topic      Freq      Term
# term
# 806       1  0.896053   academy
# 842       3  0.785690    actual
# 91        1  0.800322  actually
# 963       2  0.842495    afaict
# 92        1  0.848822     agree
# ...     ...       ...       ...
# 290       2  0.705985      well
# 995       2  0.123367      word
# 995       3  0.863568      word
# 851       4  0.898462     world
# 69        2  0.923662      year
#
# [166 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[4, 3, 1, 2])
